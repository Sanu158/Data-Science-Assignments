# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from scipy.cluster import hierarchy
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
al=pd.read_csv(r"C:\Users\sanum\Desktop\assignment\assignments data\clustering\EastWestAirlines.csv")
al.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
#Standarizng the data -  the data will be in the range of -3 to 3
Scaler = StandardScaler()

# %%
SD1 = al.drop("ID",axis=1)

# %%
#Transfroming the data into standarized data
SD = Scaler.fit_transform(SD1)

# %%
print(SD)
# Out:
# [[-4.51140783e-01 -1.86298687e-01 -7.69578406e-01 ... -3.62167870e-01
#    1.39545434e+00 -7.66919299e-01]
#  [-5.39456874e-01 -1.86298687e-01 -7.69578406e-01 ... -3.62167870e-01
#    1.37995704e+00 -7.66919299e-01]
#  [-3.20031232e-01 -1.86298687e-01 -7.69578406e-01 ... -3.62167870e-01
#    1.41192021e+00 -7.66919299e-01]
#  ...
#  [-4.29480975e-05 -1.86298687e-01  6.83121167e-01 ... -3.62167870e-01
#   -1.31560393e+00  1.30391816e+00]
#  [-1.85606976e-01 -1.86298687e-01 -7.69578406e-01 ... -9.85033311e-02
#   -1.31608822e+00 -7.66919299e-01]
#  [-7.00507951e-01 -1.86298687e-01 -7.69578406e-01 ... -3.62167870e-01
#   -1.31754109e+00 -7.66919299e-01]]

# %%
Sd = pd.DataFrame(SD)
Sd.columns=SD1.columns

# %% [markdown]
# # KMeans Clustering

# %%
# creating a object for KMeans Cluster
KM = KMeans(n_clusters=3)

# %%
#Fitting the data into model
a=KM.fit(SD)

# %%
a.labels_
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
#collecting the inertias for the clusters
inertia=[]
for k in range(1,11):
    Kmean = KMeans(n_clusters=k)
    Kmean.fit(SD)
    
    inertia.append(Kmean.inertia_)
inertia
# Out:
# [43988.999999999985,
#  35409.525700561855,
#  31874.014010827843,
#  27162.193190220714,
#  24889.428256301322,
#  22303.10573731987,
#  21199.273517232392,
#  18618.422329599496,
#  17417.331581222912,
#  15138.34836590765]

# %%
#plotting the graph for collected Inertia's
fig = plt.subplots(figsize=(5,5))
plt.plot(range(1,11),inertia,'o-')
plt.title("Graph between Inertia with respect to clusters")
plt.xlabel("No. of Clusters")
plt.ylabel("Inertia for no of clusters")
plt.show()

# %% [markdown]
# From the above graph we can observe tht optimal clusters are 5. So we now try to build a model which is having 5 clusters

# %%
#creating a model based on 5 clusters.
FinalKM = KMeans(n_clusters=5)

# %%
K=FinalKM.fit(SD)

# %%
FinalKM.labels_
# Out:
# array([2, 2, 2, ..., 1, 2, 2])

# %%
#Keeping the Labels in the dataframe for better understanding
Sd['KMeans1']=FinalKM.labels_

# %%
Grp = Sd.groupby('KMeans1')
Values = Sd.groupby('KMeans1').count()
Values
# Out:
#          Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# KMeans1
# 0            154         154        154        154        154          154
# 1            869         869        869        869        869          869
# 2           2232        2232       2232       2232       2232         2232
# 3            729         729        729        729        729          729
# 4             15          15         15         15         15           15
#
#          Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# KMeans1
# 0                154                154              154                154
# 1                869                869              869                869
# 2               2232               2232             2232               2232
# 3                729                729              729                729
# 4                 15                 15               15                 15
#
#          Award
# KMeans1
# 0          154
# 1          869
# 2         2232
# 3          729
# 4           15

# %%
Grp.agg('mean')
# Out:
#           Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# KMeans1
# 0        1.206615    0.855351   0.079402   0.165665  -0.062767     0.632206
# 1        0.313842    0.056163   1.100208  -0.082652  -0.056872     0.934785
# 2       -0.338915   -0.057765  -0.724344   0.050462  -0.060472    -0.569227
# 3        0.395493   -0.069043   0.868445  -0.088950  -0.055740     0.429536
# 4        0.639719   -0.084433   1.022084  -0.098242  15.646299     3.179691
#
#          Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# KMeans1
# 0           1.643430           3.665868         3.926661           0.277149
# 1           0.740826          -0.033117        -0.029932           0.376250
# 2          -0.617246          -0.178436        -0.190999          -0.239466
# 3           0.624289          -0.189293        -0.210262           0.221191
# 4           1.714614           0.033293         0.059695           0.239873
#
#             Award
# KMeans1
# 0        0.940849
# 1        1.303918
# 2       -0.324361
# 3       -0.766919
# 4        0.337527

# %% [markdown]
# From the above table we can observe the eman of each column, this describes how much the clusters are formed for the following columns

# %%
for x, y in Grp:
    print(y)
    print('_______________'*5)
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8     3.666042   -0.186299   0.683121   6.675367  -0.062767    -0.637398
# 42   -0.131877   -0.186299  -0.769578  -0.098242  -0.062767    -0.295878
# 50    0.342741   -0.186299  -0.769578  -0.098242  -0.062767    -0.446284
# 65   -0.195382   -0.186299   0.683121  -0.098242  -0.062767     0.688346
# 94    1.110999   -0.186299   2.135821  -0.098242  -0.062767     3.880833
# ...        ...         ...        ...        ...        ...          ...
# 3907  0.524882   -0.186299  -0.769578  -0.098242  -0.062767    -0.345240
# 3911 -0.175454    2.752037  -0.769578  -0.098242  -0.062767    -0.374394
# 3917  0.567139   -0.186299   1.409471  -0.098242  -0.062767     2.002868
# 3934  0.029710   -0.186299  -0.769578  -0.098242  -0.062767    -0.271984
# 3950 -0.138457   -0.186299  -0.769578  -0.098242  -0.062767    -0.500864
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 8        3.269747           2.421330         2.801807           1.370271
# 42       1.499394           1.992769         2.010813           1.796931
# 50      -0.687511           4.219857         0.956155           1.319905
# 65       3.478023           3.635586         7.284104           1.311188
# 94       2.853193           1.778488         3.856465           1.287942
# ...           ...                ...              ...                ...
# 3907     0.353873           3.373449         2.801807          -1.236180
# 3911     0.770426           2.602754         3.856465          -1.242960
# 3917     2.644916           4.206286         1.483484          -1.246350
# 3934    -0.999926           6.511944        -0.098503          -1.260879
# 3950     0.458011           2.492757         3.065471          -1.279766
#
#          Award  KMeans1
# 8     1.303918        0
# 42    1.303918        0
# 50   -0.766919        0
# 65    1.303918        0
# 94    1.303918        0
# ...        ...      ...
# 3907 -0.766919        0
# 3911 -0.766919        0
# 3917 -0.766919        0
# 3934 -0.766919        0
# 3950 -0.766919        0
#
# [154 rows x 12 columns]
# ___________________________________________________________________________
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
#
# 1878  0.542864   -0.186299   2.135821  -0.098242  15.304798     4.767202
# 1917  0.093086   -0.186299   2.135821  -0.098242  10.182276     3.651662
# 1946  0.528683   -0.186299   1.409471  -0.098242  20.427319     3.248854
# 2251  0.516833   -0.186299   0.683121  -0.098242  15.304798     2.112236
# 2283  0.544393   -0.186299   2.135821  -0.098242  10.182276     2.193982
# 2364  0.342186   -0.186299   2.135821  -0.098242  20.427319     8.276527
# 2955 -0.120355   -0.186299  -0.769578  -0.098242  15.304798     1.266035
# 3338  0.104668   -0.186299  -0.769578  -0.098242  20.427319     2.774693
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 106      1.499394           1.314214         2.010813           1.268570
# 384      2.124225          -0.328603        -0.362168           1.385769
# 850      2.540778           0.099958         0.165161           0.894698
# 904      0.458011          -0.328603        -0.362168           0.826413
# 1036     2.228363          -0.328603        -0.362168           0.799293
# 1244     1.915948          -0.328603        -0.362168           0.684032
# 1300     2.957332           1.207074         1.483484           0.441402
# 1878     2.124225          -0.042896         0.165161          -0.007535
# 1917     3.373885           0.385665         0.165161          -0.074852
# 1946     2.124225           0.028531        -0.098503          -0.115532
# 2251     1.603533           0.135671        -0.098503          -0.210937
# 2283     1.707671          -0.328603        -0.362168          -0.171710
# 2364     1.291118          -0.328603        -0.362168          -0.267115
# 2955     0.249734          -0.328603        -0.362168          -0.370269
# 3338    -0.479234          -0.328603        -0.362168          -1.484137
#
#          Award  KMeans1
# 106   1.303918        4
# 384   1.303918        4
# 850   1.303918        4
# 904   1.303918        4
# 1036 -0.766919        4
# 1244 -0.766919        4
# 1300 -0.766919        4
# 1878  1.303918        4
# 1917  1.303918        4
# 1946  1.303918        4
# 2251 -0.766919        4
# 2283 -0.766919        4
# 2364  1.303918        4
# 2955 -0.766919        4
# 3338 -0.766919        4
# ___________________________________________________________________________

# %% [markdown]
# So we can now observe all the records based on the cluster label

# %% [markdown]
# # DBSCAN Clustering Model

# %%
#Creating a DBScan Clustering model 
DBS = DBSCAN(eps=0.5,min_samples=20).fit(SD)

# %%
labels1=DBS.labels_

# %%
n_clusters_= len(set(labels1))-(1 if -1 in labels1 else 0)

# %%
n_clusters_
# Out:
# 5

# %% [markdown]
# So the DBSCAN model identified 5 clusters based on th given requirements

# %%
Sd['DBScan']=labels1

# %%
Grp1= Sd.groupby('DBScan')
Values1= Sd.groupby('DBScan').count()
Values1
# Out:
#         Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# DBScan
# -1         2135        2135       2135       2135       2135         2135
#  0         1348        1348       1348       1348       1348         1348
#  1          163         163        163        163        163          163
#  2          118         118        118        118        118          118
#  3          202         202        202        202        202          202
#  4           33          33         33         33         33           33
#
#         Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# DBScan
# -1             2135               2135             2135               2135
#  0             1348               1348             1348               1348
#  1              163                163              163                163
#  2              118                118              118                118
#  3              202                202              202                202
#  4               33                 33               33                 33
#
#         Award  KMeans1
# DBScan
# -1       2135     2135
#  0       1348     1348
#  1        163      163
#  2        118      118
#  3        202      202
#  4         33       33

# %%
Grp1.agg("mean")
# Out:
#          Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# DBScan
# -1      0.367849    0.162651   0.442932   0.085772   0.054799     0.450492
#  0     -0.479220   -0.186299  -0.769578  -0.098242  -0.062767    -0.639015
#  1     -0.474725   -0.186299  -0.769578  -0.098242  -0.062767    -0.591516
#  2     -0.423831   -0.186299   0.683121  -0.098242  -0.062767     0.034091
#  3     -0.010456   -0.186299   0.683121  -0.098242  -0.062767     0.021229
#  4     -0.298886   -0.186299  -0.043229  -0.098242  -0.062767    -0.372756
#
#         Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# DBScan
# -1         0.495764           0.262861         0.282112           0.244070
#  0        -0.756035          -0.301468        -0.324026          -0.326743
#  1        -0.904732          -0.282465        -0.297465          -0.245251
#  2         0.344165          -0.300154        -0.317479           0.057364
#  3         0.290462          -0.309534        -0.334757          -0.076381
#  4         0.268668          -0.328603        -0.362168          -0.969791
#
#            Award   KMeans1
# DBScan
# -1      0.397017  1.764403
#  0     -0.766919  2.000000
#  1      1.303918  2.000000
#  2      1.303918  1.000000
#  3     -0.766919  3.000000
#  4     -0.766919  2.030303

# %%
Sd
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0       -1.104065          -0.328603        -0.362168           1.395454
# 1       -0.999926          -0.328603        -0.362168           1.379957
# 2       -0.791649          -0.328603        -0.362168           1.411920
# 3       -1.104065          -0.328603        -0.362168           1.372208
# 4        1.499394           1.154932         0.692490           1.363975
# ...           ...                ...              ...                ...
# 3994    -0.791649          -0.185750        -0.098503          -1.315120
# 3995    -0.687511          -0.328603        -0.362168          -1.318994
# 3996    -0.375096          -0.328603        -0.362168          -1.315604
# 3997    -1.104065           0.028531        -0.098503          -1.316088
# 3998    -1.208203          -0.328603        -0.362168          -1.317541
#
#          Award  KMeans1  DBScan
# 0    -0.766919        2       0
# 1    -0.766919        2       0
# 2    -0.766919        2       0
# 3    -0.766919        2       0
# 4     1.303918        1      -1
# ...        ...      ...     ...
# 3994  1.303918        2       1
# 3995  1.303918        2       1
# 3996  1.303918        1      -1
# 3997 -0.766919        2       0
# 3998 -0.766919        2       0
#
# [3999 rows x 13 columns]

# %% [markdown]
# # Hierarchical Clustering - Aggloremative CLustering

# %%
#creating the Hierachy  clustering model using Agglomerative Clustering
HCluster = AgglomerativeClustering(n_clusters=5, metric="euclidean", linkage="complete")

# %%
M3=HCluster.fit(SD)
M3
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
Sd['Hier']=M3.labels_

# %%
Sd.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4  0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.104065          -0.328603        -0.362168           1.395454
# 1    -0.999926          -0.328603        -0.362168           1.379957
# 2    -0.791649          -0.328603        -0.362168           1.411920
# 3    -1.104065          -0.328603        -0.362168           1.372208
# 4     1.499394           1.154932         0.692490           1.363975
#
#       Award  KMeans1  DBScan  Hier
# 0 -0.766919        2       0     1
# 1 -0.766919        2       0     1
# 2 -0.766919        2       0     1
# 3 -0.766919        2       0     1
# 4  1.303918        1      -1     1

# %%
hr=hierarchy.linkage(SD, method='complete')

# %%
dn=hierarchy.dendrogram(hr, color_threshold=5)

# %%
Grp2= Sd.groupby('Hier')
Values2=Sd.groupby('Hier').count()
Values2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# Hier
# 0         170         170        170        170        170          170
# 1        3782        3782       3782       3782       3782         3782
# 2          15          15         15         15         15           15
# 3           4           4          4          4          4            4
# 4          28          28         28         28         28           28
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# Hier
# 0             170                170              170                170
# 1            3782               3782             3782               3782
# 2              15                 15               15                 15
# 3               4                  4                4                  4
# 4              28                 28               28                 28
#
#       Award  KMeans1  DBScan
# Hier
# 0       170      170     170
# 1      3782     3782    3782
# 2        15       15      15
# 3         4        4       4
# 4        28       28      28

# %%
Grp2.agg('mean')
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# Hier
# 0     0.431927    0.144316   0.140495   2.212754  -0.062767     0.840333
# 1    -0.076410   -0.008718  -0.018838  -0.098242  -0.058703    -0.065160
# 2     0.639719   -0.084433   1.022084  -0.098242  15.646299     3.179691
# 3     0.579559    0.262273   0.319946  -0.098242  -0.062767     2.008013
# 4     7.272823    0.309087   1.098178  -0.098242  -0.062767     1.708943
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# Hier
# 0        1.575354           2.576057         2.770787           0.282404
# 1       -0.091373          -0.135333        -0.146398          -0.022406
# 2        1.714614           0.033293         0.059695           0.239873
# 3        6.003379          13.928192        12.623311          -0.929019
# 4        1.001018           0.631654         1.116237           1.315979
#
#          Award   KMeans1    DBScan
# Hier
# 0     0.694848  0.641176 -1.000000
# 1    -0.041414  1.951877 -0.206504
# 2     0.337527  4.000000 -1.000000
# 3     1.303918  0.000000 -1.000000
# 4     1.008084  1.035714 -1.000000

# %% [markdown]
# To represent the data graphically is somewhat difficult because we have more features, and we have clustered the data based on all the features.
#
# From the above clustering models Kmeans, DBSCAN are clustered similarily with almost same data points in the same clusters. But whereaas in the Hierarchy Clustering most of the data points are labeled under cluster '1'. This shows that given parameters are efficient for the model.
